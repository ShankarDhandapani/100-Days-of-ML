# %% [markdown]
# # CSV Files

# %% [markdown]
# ## Reading CSV Files

# %%
import csv

# %%
with open("files/CSV_Data.csv") as file:
    readCSV = csv.reader(file)
    for row in readCSV:
        print(row)
# Out:
# ['Name', 'Age', 'Dept', 'City']
# ['Shankar', '20', 'CSE', 'Coimbatore']
# ['Sam', '23', 'CSE', 'Coimbatore']
# ['Sanjay', '26', 'CSE', 'Coimbatore']
# ['Sagar', '24', 'MECH', 'Coimbatore']

# %% [markdown]
# # Try catch

# %%
try:
    with open("file.txt") as file:
        readCSV = csv.reader(file)
except Exception as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'file.txt'

# %% [markdown]
# # urllib Library

# %%
from urllib import request,parse

# %%
x = request.urlopen("https://www.google.com/")
print(x.read())
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="oD8kSGWM8qHfBDB2rPsZWQ==">(function(){window.google={kEI:\'SYIcX4zwFujfz7sPvN-2uAs\',kEXPI:\'0,202123,3,4,32,567331,584254,5662,731,223,5104,207,3204,10,1226,364,926,573,817,383,246,5,1129,225,351,297,1046,1936,469,50,244,21,3,660,390,90,194,117,25,47,85,49,522,135,437,9,1120589,1197661,121,329485,13677,4855,32691,15248,867,28684,9188,8384,4859,1361,9291,3020,3897,850,8000,3033,1808,4020,978,6242,1689,5296,2055,919,874,1217,2975,6430,1141,7512,5874,4519,2777,918,2277,8,4389,1165,114,2212,530,149,1103,840,517,1137,278,107,4258,109,203,1132,4,3,2063,606,2023,1777,143,377,1947,2229,93,328,1284,16,2927,2247,1812,1788,3226,2845,7,6068,6286,4455,641,2450,2458,1226,1742,4929,108,1710,43,1654,908,2,3555,2397
# ...

# %%
url = "https://www.bing.com/search"
params = {'q':"Python try catch examples"}

# %%
data = parse.urlencode(params).encode('utf-8')
req = request.Request(url,data)
resp = request.urlopen(req)
print(resp.read())
# Out:
# b'<!doctype html><html lang="en" dir="ltr"><head><meta name="theme-color" content="#4F4F4F" /><meta name="description" content="Bing helps you turn information into action, making it faster and easier to go from searching to doing." /><meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta name="viewport" content="width=device-width, initial-scale=1.0" /><meta property="fb:app_id" content="570810223073062" /><meta property="og:type" content="website" /><meta property="og:title" content="The valleys of Munnar" /><meta property="og:image" content="https://www.bing.com/th?id=OHR.MunnarHills_EN-IN0853841800_tmb.jpg&amp;rf=" /><meta property="og:image:width" content="1366" /><meta property="og:image:height" content="768" /><meta property="og:url" content="https://www.bing.com/?form=HPFBBK&amp;ssd=20200725_1830&amp;mkt=en-IN" /><meta property="og:site_name" content="Bing" /><meta property="og:description" content="Nestled in the Western Ghats lies the hill station" /><title>Bing</titl
# ...

# %% [markdown]
# # Matplotlib

# %%
from matplotlib import pyplot as plt
from matplotlib import style

# %% [markdown]
# ## Styling and Labeling Matplotlib

# %%
style.use('ggplot')

# %%
x,y = [1,2,3,4,5],[5,6,10,8,9]

# %%
plt.plot(x,y,'g',linewidth=5,label="line 1")
plt.legend()

# %%
x2,y2 = [5,6,10,8,9],[1,2,3,4,5]

# %%
style.use('dark_background')

# %%
plt.plot(x2,y2,'c',linewidth=10,label="line 2")
plt.legend()
