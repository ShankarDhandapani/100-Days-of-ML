# %% [markdown]
# # OOPS in Python

# %% [markdown]
# # Class

# %%
class Student:
    def __init__(self,n,a):
        self.name = n
        self.age = a

# %% [markdown]
# # Object

# %%
stu_1 = Student("Ram",20)

# %%
print(stu_1.name,"is",stu_1.age,"years old.")
# Out:
# Ram is 20 years old.

# %% [markdown]
# # Method

# %%
class Email:
    def __init__(self):
        self.isMailSent = False
    def sendEmail(self):
        self.isMailSent = True

# %%
email = Email()

# %%
email.isMailSent
# Out:
# False

# %%
email.sendEmail()

# %%
email.isMailSent
# Out:
# True

# %% [markdown]
# # Inheritance
#
# * single
# * multilevel
# * hierarchical
# * multiple
# * hybrid
#
# ## Single Inheritance
# ![image.png](attachment:image.png)

# %%
class Super_Class:    
    def IAmSuperClass(self):
        print("Super class")
class Sub_class(Super_Class):
    def IAmSubClass(self):
        print("Sub Class")

# %%
super_class = Super_Class()
super_class.IAmSuperClass()
# Out:
# Super class

# %%
sub_class = Sub_class()
sub_class.IAmSubClass()
sub_class.IAmSuperClass()
# Out:
# Sub Class
# Super class

# %% [markdown]
# # Multiple Inheritance
#
# <img src="https://github.com/ShankarDhandapani/Python/raw/0bd94a7b40678935bb993f921e50aa0602207bb3/Img/Multiple.jpg"/>

# %%
class SuperClass1:
    def IAmSuper1(self):
        print("Super 1")

class SuperClass2:
    def IAmSuper2(self):
        print("Super 2")
        
class SubClass(SuperClass1,SuperClass2):
    def IAmSubClass(self):
        print("Sub Class")

# %%
super1 = SuperClass1()
super1.IAmSuper1()
# Out:
# Super 1

# %%
super2 = SuperClass2()
super2.IAmSuper2()
# Out:
# Super 2

# %%
sub = SubClass()
sub.IAmSubClass()
sub.IAmSuper1()
sub.IAmSuper2()
# Out:
# Sub Class
# Super 1
# Super 2

# %% [markdown]
# # Multilevel Inheritance
#
# <img src="https://github.com/ShankarDhandapani/Python/raw/0bd94a7b40678935bb993f921e50aa0602207bb3/Img/Multilevel.jpg"/>

# %%
class SuperClass:
    def IAmSuper(self):
        print("Super")
        
class Sub1(SuperClass):
    def IAmSub1(self):
        print("Sub 1")
        
class Sub2(Sub1):
    def IAmSub2(self):
        print("Sub 2")

# %%
superClass = SuperClass()
superClass.IAmSuper()
# Out:
# Super

# %%
sub1 = Sub1()
sub1.IAmSub1()
sub1.IAmSuper()
# Out:
# Sub 1
# Super

# %%
sub2 = Sub2()
sub2.IAmSub2()
sub2.IAmSub1()
sub2.IAmSuper()
# Out:
# Sub 2
# Sub 1
# Super

# %% [markdown]
# # Hierarchical Inheritance
#
# <img src="https://github.com/ShankarDhandapani/Python/raw/0bd94a7b40678935bb993f921e50aa0602207bb3/Img/hierarchical.jpg" />

# %%
class SuperClass:
    def IAmSuper(self):
        print("Super")
        
class Sub1(SuperClass):
    def IAmSub1(self):
        print("Sub 1")
        
class Sub2(SuperClass):
    def IAmSub2(self):
        print("Sub 2")
        
class Sub3(SuperClass):
    def IAmSub3(self):
        print("Sub 3")

# %%
superClass = SuperClass()
superClass.IAmSuper()
# Out:
# Super

# %%
sub1 = Sub1()
sub1.IAmSub1()
sub1.IAmSuper()
# Out:
# Sub 1
# Super

# %%
sub2 = Sub2()
sub2.IAmSub2()
sub2.IAmSuper()
# Out:
# Sub 2
# Super

# %%
sub3 = Sub3()
sub3.IAmSub3()
sub3.IAmSuper()
# Out:
# Sub 3
# Super

# %% [markdown]
# # Hybrid Inheritance
#
# <img src="https://github.com/ShankarDhandapani/Python/raw/0bd94a7b40678935bb993f921e50aa0602207bb3/Img/Hybrid.jpg"/>

# %%
class SuperClass:
    def IAmSuper(self):
        print("Super")
        
class Sub1(SuperClass):
    def IAmSub1(self):
        print("Sub 1")
        
class Sub2(SuperClass):
    def IAmSub2(self):
        print("Sub 2")
        
class Sub3(Sub1, Sub2):
    def IAmSub3(self):
        print("Sub 3")

# %%
superClass = SuperClass()
superClass.IAmSuper()
# Out:
# Super

# %%
sub1 = Sub1()
sub1.IAmSub1()
sub1.IAmSuper()
# Out:
# Sub 1
# Super

# %%
sub2 = Sub2()
sub2.IAmSub2()
sub2.IAmSuper()
# Out:
# Sub 2
# Super

# %%
sub3 = Sub3()
sub3.IAmSub1()
sub3.IAmSub2()
sub3.IAmSub3()
sub3.IAmSuper()
# Out:
# Sub 1
# Sub 2
# Sub 3
# Super

# %% [markdown]
# # Abstraction

# %%
from abc import ABC, abstractmethod 
  
class Shapes(ABC):
    @abstractmethod
    def no_of_sides(self):
        pass
    
class Square(Shapes):
    def no_of_sides(self):
        print("4 Sides")
        
class Rectangle(Shapes):
    def display(self):
        print("Hi")
        
class Triangle(Shapes):
    def no_of_sides(self):
        print("3 Sides")

# %%
square = Square()
square.no_of_sides()
# Out:
# 4 Sides

# %%
rectangle = Rectangle()
rectangle.display()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-beab8ec7dd23> in <module>
# ----> 1 rectangle = Rectangle()
#       2 rectangle.display()
#
# TypeError: Can't instantiate abstract class Rectangle with abstract methods no_of_sides

# %%
triangle = Triangle()
triangle.no_of_sides()
# Out:
# 3 Sides

# %% [markdown]
# # Encapsulation
#
# <img src="https://github.com/ShankarDhandapani/Python/raw/0bd94a7b40678935bb993f921e50aa0602207bb3/Img/Encapsulation.png"/>

# %%
class Base:
    def __init__(self):
        self.public = 1
        self._protected = 2
        self.__private = 3
    def display(self):
        print("Protected =",self._protected)
        print("Private =",self.__private)
        
class Derived(Base):
    def __init__(self):
        Base.__init__(self)
        print("Public :",self.public)
        print("Protected :",self._protected)
        print("Private :",self.__private)

# %%
base = Base()
print("Public =",base.public)
print("Protected =",base._protected)
print("Private =",base.__private)
# Out:
# Public = 1
# Protected = 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-17f8942db81e> in <module>
#       2 print("Public =",base.public)
#       3 print("Protected =",base._protected)
# ----> 4 print("Private =",base.__private)
#
# AttributeError: 'Base' object has no attribute '__private'

# %%
base.display()
# Out:
# Protected = 2
# Private = 3

# %%
derived = Derived()
# Out:
# Public : 1
# Protected : 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-8b1f9d30210c> in <module>
# ----> 1 derived = Derived()
#
# <ipython-input-34-50fa178bca4a> in __init__(self)
#      13         print("Public :",self.public)
#      14         print("Protected :",self._protected)
# ---> 15         print("Private :",self.__private)
#
# AttributeError: 'Derived' object has no attribute '_Derived__private'
